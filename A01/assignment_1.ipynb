# %% [markdown]
# # Starter Code from Gabriel Vigliensoni
# # https://colab.research.google.com/drive/1c5XF5MQqoYefrgxp9iptn4cGPi83qqc2?usp=sharing

# %%
# Importing AI Framework
# ALWAYS START WITH THIS CODE!

import torch

# Torch (and PyTorch) PyTorch is one of the most popular frameworks for
#  developing and training machine learning and deep learning models.

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# CUDA (Compute Unified Device Architecture) is a parallel computing platform
# and programming model developed by NVIDIA for their GPUs. CUDA harness the
# highly parallel processing power of GPUs to perform general-purpose computing
# tasks (i.e., tasks beyond traditional graphics rendering).
# Out:
# Using device: cuda

# %%
# Prompt 1
# Image Generation
# Model: stable-diffusion-v1-5-GGUF by Runway ML
# https://huggingface.co/gpustack/stable-diffusion-v1-5-GGUF
# Code from Runway ML

from diffusers import StableDiffusionPipeline

model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "plants growing on computers, early computer art, surreal"
pipe(prompt).images[0]
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# Prompt 2
# Image Generation
# Model: stable-diffusion-v1-5-GGUF by Runway ML
# https://huggingface.co/gpustack/stable-diffusion-v1-5-GGUF
# Code from Runway ML

from diffusers import StableDiffusionPipeline

model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "old computers growing flowers in an office, early computer art, surreal"
pipe(prompt).images[0]
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# Prompt 3
# Image Generation
# Model: stable-diffusion-v1-5-GGUF by Runway ML
# https://huggingface.co/gpustack/stable-diffusion-v1-5-GGUF
# Code from Runway ML

from diffusers import StableDiffusionPipeline

model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "vintage, row of computers, colorful flowers in an office, early computer art, surreal"
pipe(prompt).images[0]
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
